# %% [markdown]
# <a href="https://colab.research.google.com/github/NaydelinAidee/Simulaci-nI/blob/main/colores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NAYDELIN AIDEE CARCAMO  HERNANDEZ

# %% [markdown]
# Realizaremos el codigo de elsiguiente ejercicio

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

def lanzamiento():
  m = np.random.binomial(1,0.5,2)
  return m

lanzamiento()
# Out:
# array([1, 0])

# %%
def saltos():
  lista = []
  for _ in range(n):
    M1 = random.randint(0, 1)
    M2 = random.randint(0, 1)
    if M1 == 0 and M2 == 0:
      return 2
    elif (M1 == 0 and M2 == 1) or (M1 == 1 and M2 == 0):
      return 1
    else:
      return 0

# %%
def prob_mon(n):
  lista = []
  for _ in range(n):
    M1 = random.randint(0, 1)
    M2 = random.randint(0, 1)
    if M1 == M2:
      lista.append(1/4)
    else:
      lista.append(1/2)
  return lista

# %%
def colores(n):
    mi_diccionario = {
    "Naranja": 1,
    "Azul": 2,
    "Verde": 3,
    "Rojo": 4
}
    c = []
    juego = 1
    for i in range(n):
        juego += saltos(n)
        c.append(juego)
    return juego

# %%
def colores(n):
    mi_diccionario = ["Naranja", "Azul", "Verde", "Rojo"]
    puntajes = []
    juego = 0
    for _ in range(n):
        juego += saltos()
        color = mi_diccionario[juego % len(mi_diccionario)]
        puntajes.append((juego, color))
    return puntajes
